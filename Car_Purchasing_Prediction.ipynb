# %%
import pandas as pd
car_dataframe = pd.read_csv('Car_Purchasing_Data.csv', encoding='ISO-8859-1')
car_dataframe.tail(5)

# %%
import seaborn as sns
sns.pairplot(car_dataframe)

# %%
X=car_dataframe.drop(['Customer Name','Customer e-mail','Country','Car Purchase Amount'], axis=1)
X
y=car_dataframe['Car Purchase Amount']
y.head(5)
X

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
y_scaled = scaler.fit_transform(y.values.reshape(-1,1))
y_scaled

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y_scaled,test_size=0.25)
X_train.shape
# Out:
# (400, 5)

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(25, input_dim =5, activation='relu'))
model.add(Dense(25, activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.summary()

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
